# %%
from ase.build import bulk, diamond100, diamond111
from ase.visualize import view
from ase.optimize import BFGS
from pyace import PyACECalculator
import numpy as np

calc = PyACECalculator('output_potential.yaml')

bulk = bulk('Si', 'diamond', a=5.4422, cubic=True)
bulk.calc = calc
bulk_energy = bulk.get_total_energy()

supercell = bulk.repeat((4, 4, 4))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from ase.build import bulk, diamond100, diamond111
#       2 from ase.visualize import view
#       3 from ase.optimize import BFGS
#
# ModuleNotFoundError: No module named 'ase'

# %%
view(bulk, viewer='ngl')
